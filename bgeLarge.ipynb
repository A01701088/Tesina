# %%
import nest_asyncio
from dotenv import load_dotenv
from IPython.display import Markdown, display
import re
from nltk.corpus import stopwords
import nltk
from nltk.translate.meteor_score import meteor_score
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from llama_index.core import Settings
from llama_index.llms.ollama import Ollama
from llama_index.core import PromptTemplate
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import VectorStoreIndex, ServiceContext, SimpleDirectoryReader

# %%
questions =[
    {
        "question":"What is the definition of an accident according to the contract?",
        "ground_truth": "Sudden, unforeseen, and violent event caused by an external factor that results in injuries requiring medical attention to the insured within 90 days subsequent to the event."
    },
    {
        "question": "What is covered during a stay at the hospital?",
        "ground_truth": "So, according to this information, the following are covered during a stay at the hospital: Private standard room with bathroom, Food provided, Laboratory tests, cabinet, image, and diagnostic agents related to the diagnosis of the covered accident or disease Operating room, healing, recovery, emergency, intensive care, intermediate, or coronary care unit, Blood transfusions and blood compatibility tests, Medications administered in the hospital that comply with the definition in these general conditions, are indicated and justified by the attending physician, and are related to the covered accident or disease, Expenses for an additional bed for the policyholder's companion affected and General nursing care"
    },
    {
        "question": "What rehabilitation therapy is covered by the insurance?",
        "ground_truth": "Rehabilitation musculoskeletal (30 sessions), Hydrotherapy (30 sessions), Neurorehabilitation (180 sessions), Therapy for motor disorders (90 sessions), exclusively for newborns with AXA benefit, Speech therapy (30 sessions), Inhalation therapy or pulmonary physiotherapy, as indicated by the attending physician, Cardiac rehabilitation (40 sessions)"
    },
    {
        "question": "What is the coverage for accidents that need dental work??",
        "ground_truth": "Consultation of emergency dental care at normal hours once a year without cost, Diagnosis, treatment plan, and prevention, 2 cleanings per year without cost (for adults and children), Radiographs (1 radiograph per year) with 30% co-pay, Dental operation (amalgams and resins) with 30% co-pay, Endodontics (root canal treatments, pulpectomies, and pulpotomias) with 30% co-pay and a 10% discount for other treatments, Minor surgery (minor surgical procedures) with 30% co-pay, Major surgery (major surgical procedures) with a 15% discount, Third molars (wisdom teeth) with a 20% discount, Prosthetics (crowns, onlays, posts) with a 10% discount, Periodontology (1 periodontal evaluation per year without cost) with 30% co-pay and a 10% discount for other treatments, Orthodontics (brackets) with a 10-20% discount for bracket removal, Whitening (Zoom and at-home) with a 20% discount"
    },
    {
        "question": "What is the policy regarding surgery by robot?",
        "ground_truth":"The policy covers surgery by robot for specific procedures, including prostatectomy, hysterectomy due to endometrial cancer, ovarian cancer, cervical-uterine cancer, renal cancer, and others. However, only surgeons with expertise in minimally invasive surgery and recertification in the relevant specialty will be covered, provided they have performed at least 20 robotic surgeries for that specific procedure."

    },
    {
        "question": "What is the coverage for COVID-19?",
        "ground_truth":"For the insured with a policy effective date after February 9, 2022, COVID-19 medical expenses are fully covered if they have completed the complete vaccination schedule as per the National Vaccination Plan. For those without the complete vaccination schedule, COVID-19 medical expenses are partially covered up to $300,000."
    },
    {
        "question": "What is the coverage for medication outside the hospital?",
        "ground_truth":"Medicamentos Fuera del Hospital (MFH): Medications purchased outside the hospital are covered, even if other additional coverages such as Emergencia Médica en el Extranjero (EMER), Enfermedades Cubiertas en el Extranjero (ECE), or Atención en el Extranjero (ATEX) are contracted."
    },
    {
        "question":"What is your deductible for an accident?",
        "ground_truth":"$0 (zero pesos), as per the policy conditions, after the accidental coverage has been contracted. The deductible will only be applicable if the total cost of the accident is less than $2,000."

    },
    {
        "question":"What is the coverage if you are out of country?",
        "ground_truth":"Enfermedades Cubiertas en el Extranjero (ECE), if you are out of country, this coverage provides medical expenses for certain diseases such as cancer and cerebrovascular/cerebral diseases, but only if the diagnosis and initial costs occurred within Mexico."
    },
    {
        "question":"What is Planmed?",
        "ground_truth":"Planmed is a medical coverage offered by AXA Flex Plus 2024, providing benefits such as Check Up, Consultas de Atención Primaria (Primary Care), Atención no programada (Non-programmed Attention), and Consultas de Especialidad (Specialty Consultations)."
    },
    {
        "question":"What are the rules if I get injured in a racecar?",
        "ground_truth": "According to section 35 of the policy, injuries sustained by the insured while traveling as an occupant (driver or passenger) of a vehicle, including a racecar, during racing, endurance, or speed tests, are not covered."
    },
    {
        "question":"What is the coverage for a heart attack?",
        "ground_truth":"Coverage includes surgical intervention for coronary heart disease, provided the need for such interventions is demonstrated through coronary angiography."
    },
    {
        "question":"What is the coverage for a heart transplant?",
        "ground_truth":"The coverage for a heart transplant includes: The surgical procedure, Hospitalization expenses (as per the contracted table), Donor-related expenses, including those incurred by the donor during the donation process, Expenses related to procurement and transportation are not covered."
    },
    {
        "question":"What is the coverage for a kidney transplant?",
        "ground_truth":"This policy covers the procedure for kidney transplantation, but excludes post-surgical costs. Additionally, it also covers the donor's medical expenses if they are alive during the donation process, and only the recipient's expenses if the donor is deceased."
    },
    {
        "question":"What is the policy on hyperbaric medicine?",
        "ground_truth":"According to the conditions, any costs related to Hyperbaric Treatments are not covered, unless specified under coverage 16."
    }
    


]

# %%
nltk.download('stopwords')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))

def tokenize(text):
    tokens = re.findall(r'\b\w+\b', text.lower())
    filtered_tokens = [word for word in tokens if word not in stop_words]
    return filtered_tokens

def calculate_f1(predicted_answer, ground_truth_answer):
    pred_tokens = set(tokenize(predicted_answer))
    gt_tokens = set(tokenize(ground_truth_answer))

    common_tokens = pred_tokens.intersection(gt_tokens)
    if len(common_tokens) == 0:
        return 0.0

    precision = len(common_tokens) / len(pred_tokens)
    recall = len(common_tokens) / len(gt_tokens)
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def rouge_1(predicted_answer, ground_truth_answer):
    pred_tokens = tokenize(predicted_answer)
    gt_tokens = tokenize(ground_truth_answer)
    overlapping_tokens = set(pred_tokens).intersection(gt_tokens)
    return len(overlapping_tokens) / len(gt_tokens) if gt_tokens else 0

def cosine_sim(predicted_answer, ground_truth_answer):
    vectorizer = CountVectorizer().fit([predicted_answer, ground_truth_answer])
    vectors = vectorizer.transform([predicted_answer, ground_truth_answer])
    return cosine_similarity(vectors)[0, 1]

def jaccard_similarity(predicted_answer, ground_truth_answer):
    pred_tokens = set(tokenize(predicted_answer))
    gt_tokens = set(tokenize(ground_truth_answer))
    intersection = len(pred_tokens.intersection(gt_tokens))
    union = len(pred_tokens.union(gt_tokens))
    return intersection / union if union != 0 else 0

def calculate_meteor(predicted_answer, ground_truth_answer):
    gt_tokens = tokenize(ground_truth_answer)
    pred_tokens = tokenize(predicted_answer)
    return meteor_score([gt_tokens], pred_tokens)
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\SPARTAN
# [nltk_data]     PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\SPARTAN
# [nltk_data]     PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
nest_asyncio.apply()

# %%
input_dir_path = './Docs/'

# %%
llm=Ollama(model="llama3.1:8b", request_timeout=120.0)
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-large-en-v1.5", trust_remote_code=True)

# %%
# load data
loader = SimpleDirectoryReader(
            input_dir = input_dir_path,
            recursive=True
        )
docs = loader.load_data()
Settings.embed_model = embed_model
index = VectorStoreIndex.from_documents(docs, show_progress=True)

Settings.llm = llm
query_engine = index.as_query_engine()
# Out:
# Parsing nodes: 100%|██████████| 107/107 [00:00<00:00, 1495.09it/s]
# Generating embeddings: 100%|██████████| 138/138 [01:34<00:00,  1.46it/s]

# %%
qa_prompt_tmpl_str = (
"Context information is below.\n"
"---------------------\n"
"{context_str}\n"
"---------------------\n"
"Given the context information above I want you to give clear and concise answers. Translate EVERY word from Spanish to English, including procedures, and do not write the Spanish words.\n"
"Query: {query_str}\n"
"Answer: "
)
qa_prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str)

query_engine.update_prompts(
    {"response_synthesizer:text_qa_template": qa_prompt_tmpl}
)

f1_scores = []
rouge_scores = []
cosine_scores = []
jaccard_scores = []
meteor_scores = []
average_f1 = []
average_rouge = []
average_cosine = []
average_jaccard = []
average_meteor = []
for i in range(50):
    for qa_pair in questions:
        question = qa_pair["question"]
        ground_truth = qa_pair["ground_truth"]
        
        # Get the AI's answer for the current question
        predicted_answer = query_engine.query(question,)
        
        # Calculate the F1 score for this pair
        f1 = calculate_f1(str(predicted_answer), ground_truth)
        rogue = rouge_1(str(predicted_answer), ground_truth)
        cosine = cosine_sim(str(predicted_answer), ground_truth)
        jaccard = jaccard_similarity(str(predicted_answer), ground_truth)
        meteor = calculate_meteor(str(predicted_answer), ground_truth)
        f1_scores.append(f1)
        rouge_scores.append(rogue)
        cosine_scores.append(cosine)
        jaccard_scores.append(jaccard)
        meteor_scores.append(meteor)

        # Print the F1 score for this question-answer pair
        print(f"Question: {question}")
        print(f"Ground Truth: {ground_truth}")
        print(f"Predicted Answer: {predicted_answer}")
        print(f"F1 Score: {f1}\n")
        print(f"Rouge Score: {rogue}\n")
        print(f"Cosine Similarity: {cosine}\n")
        print(f"Jaccard Similarity: {jaccard}\n")   
        print(f"Meteor Score: {meteor}\n")
    

    average_f1.append(sum(f1_scores) / len(f1_scores))
    average_rouge.append(sum(rouge_scores) / len(rouge_scores))
    average_cosine.append(sum(cosine_scores) / len(cosine_scores))
    average_jaccard.append(sum(jaccard_scores) / len(jaccard_scores))
    average_meteor.append(sum(meteor_scores) / len(meteor_scores))


print("Average F1 Score over 50 runs:", sum(average_f1)/ len(average_f1))
print("Average Rouge Score over 50 runs:", sum(average_rouge)/ len(average_rouge))
print("Average Cosine Similarity over 50 runs:", sum(average_cosine)/ len(average_cosine))
print("Average Jaccard Similarity over 50 runs:", sum(average_jaccard)/ len(average_jaccard))
print("Average Meteor Score over 50 runs:", sum(average_meteor)/ len(average_meteor))
# Out:
# Question: What is the definition of an accident according to the contract?
# Ground Truth: Sudden, unforeseen, and violent event caused by an external factor that results in injuries requiring medical attention to the insured within 90 days subsequent to the event.
# Predicted Answer: There is no explicit definition of "accident" in the provided text. However, based on the context and surrounding information, it appears that "Siniestro" ( translated as Accident or Loss) refers to a medical emergency or illness, rather than a physical accident.
#
# In Section 28, the contract discusses the payment of indemnities for Siniestros, which seems to be related to medical expenses. The term "Accidente" is not explicitly defined in the text, but it can be inferred that it refers to a medical event or condition that triggers the insurance coverage.
# F1 Score: 0.07017543859649122
#
# Rouge Score: 0.1111111111111111
#
# Cosine Similarity: 0.43397576260490744
#
# Jaccard Similarity: 0.03636363636363636
#
# Meteor Score: 0.07211538461538462
#
# Question: What is covered during a stay at the hospital?
# Ground Truth: So, according to this information, the following are covered during a stay at the hospital: Private standard room with bathroom, Food provided, Laboratory tests, cabinet, image, and diagnostic agents related to the diagnosis of the covered accident or disease Operating room, healing, recovery, emergency, intensive care, intermediate, or coronary care unit, Blood transfusions and blood compatibility tests, Medications administered in the hospital that comply with the definition in these general conditions, are indicated and justified by the attending physician, and are related to the covered accident or disease, Expenses for an additional bed for the policyholder's companion affected and General nursing care
# Predicted Answer: The following are covered during a stay at the hospital:
#
# * Medical care
# * Hospitalization
# * Surgical treatments
# * Medications
# * Nursing care
#
# Note that "Cuidados en casa o fuera del Hospital" translates to "Care in the home or outside of the hospital", which indicates that the coverage is for care outside of the hospital, not during a stay at the hospital.
# F1 Score: 0.19178082191780824
#
# Rouge Score: 0.1111111111111111
#
# Cosine Similarity: 0.6155421417578842
#
# Jaccard Similarity: 0.10606060606060606
#
# Meteor Score: 0.09197324414715718
#
# Question: What rehabilitation therapy is covered by the insurance?
# Ground Truth: Rehabilitation musculoskeletal (30 sessions), Hydrotherapy (30 sessions), Neurorehabilitation (180 sessions), Therapy for motor disorders (90 sessions), exclusively for newborns with AXA benefit, Speech therapy (30 sessions), Inhalation therapy or pulmonary physiotherapy, as indicated by the attending physician, Cardiac rehabilitation (40 sessions)
# Predicted Answer: The following rehabilitation therapies are covered by the insurance:
#
# * 30 sessions for musculoskeletal rehabilitation
# * 30 sessions for hydrotherapy
# * 180 sessions for neurorehabilitation
# * 90 sessions for motor therapy, only for newborns with AXA benefit
# * 30 sessions of deglutition therapy
# * 365 sessions for neurodevelopment
# * Inhalation therapy or pulmonary physiotherapy, as indicated by the treating doctor
# * 40 sessions for cardiac rehabilitation
# F1 Score: 0.7307692307692307
#
# Rouge Score: 0.5588235294117647
#
# Cosine Similarity: 0.8519673616583817
#
# Jaccard Similarity: 0.5757575757575758
#
# Meteor Score: 0.7385998715478483
#
# Question: What is the coverage for accidents that need dental work??
# Ground Truth: Consultation of emergency dental care at normal hours once a year without cost, Diagnosis, treatment plan, and prevention, 2 cleanings per year without cost (for adults and children), Radiographs (1 radiograph per year) with 30% co-pay, Dental operation (amalgams and resins) with 30% co-pay, Endodontics (root canal treatments, pulpectomies, and pulpotomias) with 30% co-pay and a 10% discount for other treatments, Minor surgery (minor surgical procedures) with 30% co-pay, Major surgery (major surgical procedures) with a 15% discount, Third molars (wisdom teeth) with a 20% discount, Prosthetics (crowns, onlays, posts) with a 10% discount, Periodontology (1 periodontal evaluation per year without cost) with 30% co-pay and a 10% discount for other treatments, Orthodontics (brackets) with a 10-20% discount for bracket removal, Whitening (Zoom and at-home) with a 20% discount
# Predicted Answer: According to the provided information, the coverage for accidents that need dental work includes:
#
# * Consulta de emergencia dental en horario normal (Emergency Dental Consultation during regular hours) - 1 time per year with no cost
# * Diagnóstico, plan de tratamiento y prevención (Diagnosis, treatment plan, and prevention) - not specified as having a specific cost or co-insurance rate
# * Limpiezas (Cleanings) - 2 times per year for adults and children with 0% co-insurance
# * Radiografías (Radiographs) - 1 time per year with no cost, but subsequent radiographs have a 30% co-insurance rate
# * Operatoria dental (Dental procedures including amalgams and resins) - 30% co-insurance rate
# * Endodoncias (Root canal treatments) - 30% co-insurance rate, plus discounts of up to 10% on other treatments
# * Cirugía básica (Basic surgical procedures) - 30% co-insurance rate
# * Cirugía avanzada (Advanced surgical procedures) - discounts starting from 15%
# * Terceros molares (Wisdom teeth removal) - discounts starting from 20%
# * Prótesis (Crowns, onlays, posts) - 50% co-insurance rate for this specific service under Protección Dental Integral (PDI)
#
# Please note that some services have additional discounts or rates under specific conditions, but the above list only includes information relevant to the original question.
# F1 Score: 0.47368421052631576
#
# Rouge Score: 0.3564356435643564
#
# Cosine Similarity: 0.4752360735063087
#
# Jaccard Similarity: 0.3103448275862069
#
# Meteor Score: 0.4508928571428571
#
# Question: What is the policy regarding surgery by robot?
# Ground Truth: The policy covers surgery by robot for specific procedures, including prostatectomy, hysterectomy due to endometrial cancer, ovarian cancer, cervical-uterine cancer, renal cancer, and others. However, only surgeons with expertise in minimally invasive surgery and recertification in the relevant specialty will be covered, provided they have performed at least 20 robotic surgeries for that specific procedure.
# Predicted Answer: The policy covers surgery by robot only for the following procedures:
#
# * Prostatectomy
# * Hysterectomy due to endometrial cancer
# * Hysterectomy due to ovarian cancer
# * Hysterectomy due to cervical-uterine cancer
# * Nephrectomy due to renal cancer
# * Partial nephrectomy due to renal cancer
# * Colectomy due to colon cancer
# * Replacement of the mitral valve
#
# The surgery must be performed by a specialist in minimally invasive surgery with valid recertification, and the surgeon must have a minimum of 20 robot-assisted surgeries for the specific procedure.
# F1 Score: 0.6376811594202899
#
# Rouge Score: 0.5789473684210527
#
# Cosine Similarity: 0.6872564503672765
#
# Jaccard Similarity: 0.46808510638297873
#
# Meteor Score: 0.5355854462997319
#
# Question: What is the coverage for COVID-19?
# Ground Truth: For the insured with a policy effective date after February 9, 2022, COVID-19 medical expenses are fully covered if they have completed the complete vaccination schedule as per the National Vaccination Plan. For those without the complete vaccination schedule, COVID-19 medical expenses are partially covered up to $300,000.
# Predicted Answer: The coverage for COVID-19 is not explicitly mentioned in the provided text. However, based on the information provided:
#
# * Accidente or Enfermedad (Accident or Illness) is defined as "Toda alteración de la salud que resulte de la acción de agentes de origen interno o externo en el estado fisiológico del organismo y amerite Tratamiento médico o quirúrgico" (Any alteration of health resulting from the action of internal or external agents on the physiological state of the organism and requiring medical or surgical treatment).
# * Enfermedad Preexistente (Pre-existing Illness) is defined as "Aquellas cuyo diagnóstico se haya realizado con anterioridad a la celebración del Contrato de Seguro" (Those whose diagnosis has been made prior to the celebration of the Insurance Contract).
#
# It is likely that COVID-19 would be considered an Enfermedad, but it would not be covered if it were a Pre-existing condition. However, this is not explicitly stated in the provided text.
#
# To confirm coverage for COVID-19, you should refer to the specific policy or contract documents.
# F1 Score: 0.09345794392523364
#
# Rouge Score: 0.15151515151515152
#
# Cosine Similarity: 0.3655966816875307
#
# Jaccard Similarity: 0.049019607843137254
#
# Meteor Score: 0.18370370370370373
#
# Question: What is the coverage for medication outside the hospital?
# Ground Truth: Medicamentos Fuera del Hospital (MFH): Medications purchased outside the hospital are covered, even if other additional coverages such as Emergencia Médica en el Extranjero (EMER), Enfermedades Cubiertas en el Extranjero (ECE), or Atención en el Extranjero (ATEX) are contracted.
# Predicted Answer: The coverage for medication outside the hospital includes the costs of administering medications that require special handling, preparation, or administration, as well as rehabilitation pulmonary and home parenteral nutrition. This will be paid for a maximum period of 30 days continuously or 720 hours in discontinuous periods and per each incident.
#
# In addition, the cost of oxygen medicinal consumption is also covered, provided it is indicated and justified by a medical prescription that is not more than 3 months old. The prescription must be delivered to the company for periods of 30 natural days.
#
# The company will provide the oxygen tank during the time needed, and the policyholder must return it to the company at the end of treatment or coverage under this policy.
# F1 Score: 0.09638554216867469
#
# Rouge Score: 0.12903225806451613
#
# Cosine Similarity: 0.1529881927068027
#
# Jaccard Similarity: 0.05063291139240506
#
# Meteor Score: 0.1228786423310919
#
# Question: What is your deductible for an accident?
# Ground Truth: $0 (zero pesos), as per the policy conditions, after the accidental coverage has been contracted. The deductible will only be applicable if the total cost of the accident is less than $2,000.
# Predicted Answer: According to the conditions of the AXA Flex Plus 2024 policy, the deductible for an accident is zero pesos (0$), as long as the total amount of covered expenses exceeds $2,000.
# F1 Score: 0.5405405405405405
#
# Rouge Score: 0.5882352941176471
#
# Cosine Similarity: 0.6813181146876505
#
# Jaccard Similarity: 0.37037037037037035
#
# Meteor Score: 0.4300578034682081
#
# Question: What is the coverage if you are out of country?
# Ground Truth: Enfermedades Cubiertas en el Extranjero (ECE), if you are out of country, this coverage provides medical expenses for certain diseases such as cancer and cerebrovascular/cerebral diseases, but only if the diagnosis and initial costs occurred within Mexico.
# Predicted Answer: If you are out of country, this policy provides coverage for hospitalizations abroad under certain conditions.
#
# The conditions require:
#
# * Giving notice to the Company from the start of illness or within 10 days after diagnosis
# * Providing prior notification to the Company 10 days before being hospitalized abroad
# * Not having initiated medical treatment related to that illness
#
# This applies only if you have additional coverage with cost, such as Atención en el Extranjero (ATEX) and Enfermedades Cubiertas en el Extranjero (ECE).
#
# For subsequent surgeries related to the same illness, this benefit will apply, provided it was applied from the first surgery.
#
# The diagnosis will be determined based on initial medical information provided by the doctor who established the definitive diagnosis, as well as studies that evidenced the illness.
#
# Additionally, a 5% discount on hospital expenses will be applied once you have met the previous conditions.
# F1 Score: 0.35714285714285715
#
# Rouge Score: 0.6521739130434783
#
# Cosine Similarity: 0.4499770425732575
#
# Jaccard Similarity: 0.21739130434782608
#
# Meteor Score: 0.46529134114583337
#
# Question: What is Planmed?
# Ground Truth: Planmed is a medical coverage offered by AXA Flex Plus 2024, providing benefits such as Check Up, Consultas de Atención Primaria (Primary Care), Atención no programada (Non-programmed Attention), and Consultas de Especialidad (Specialty Consultations).
# Predicted Answer: Planmed refers to a medical coverage or insurance plan.
# F1 Score: 0.2
#
# Rouge Score: 0.1111111111111111
#
# Cosine Similarity: 0.16770509831248423
#
# Jaccard Similarity: 0.1111111111111111
#
# Meteor Score: 0.1493975903614458
#
# Question: What are the rules if I get injured in a racecar?
# Ground Truth: According to section 35 of the policy, injuries sustained by the insured while traveling as an occupant (driver or passenger) of a vehicle, including a racecar, during racing, endurance, or speed tests, are not covered.
# Predicted Answer: According to the policy, Lesions that the Insured suffers when traveling as an occupant of any automobile (driver or copilot), motorcycle, or similar vehicle in races, endurance tests, or speed trials, motorcycling, or practicing sports with a motor vehicle in any of its modalities will be covered.
# F1 Score: 0.5116279069767442
#
# Rouge Score: 0.5789473684210527
#
# Cosine Similarity: 0.6019701189699784
#
# Jaccard Similarity: 0.34375
#
# Meteor Score: 0.46235358048544867
#
# Question: What is the coverage for a heart attack?
# Ground Truth: Coverage includes surgical intervention for coronary heart disease, provided the need for such interventions is demonstrated through coronary angiography.
# Predicted Answer: The coverage for a heart attack includes intervention surgical procedures of the thorax open for the placement of hemoducts for myocardial revascularization. The need for this type of interventions must be demonstrated by coronary angiography.
#
# Note: Myocardial revascularization refers to a medical procedure that aims to restore blood flow to the heart muscle, typically after a heart attack.
# F1 Score: 0.47619047619047616
#
# Rouge Score: 0.7692307692307693
#
# Cosine Similarity: 0.5145741206629915
#
# Jaccard Similarity: 0.3125
#
# Meteor Score: 0.48947368421052634
#
# Question: What is the coverage for a heart transplant?
# Ground Truth: The coverage for a heart transplant includes: The surgical procedure, Hospitalization expenses (as per the contracted table), Donor-related expenses, including those incurred by the donor during the donation process, Expenses related to procurement and transportation are not covered.
# Predicted Answer: The coverage includes the surgical procedure for a heart transplant. The costs of the donor (if living) are also covered, excluding pre- and post-surgical expenses and any compensation received by the donor. If the donor is cadaveric, only the costs of the recipient are covered.
# F1 Score: 0.46153846153846156
#
# Rouge Score: 0.375
#
# Cosine Similarity: 0.7055581819238779
#
# Jaccard Similarity: 0.3
#
# Meteor Score: 0.2647916666666667
#
# Question: What is the coverage for a kidney transplant?
# Ground Truth: This policy covers the procedure for kidney transplantation, but excludes post-surgical costs. Additionally, it also covers the donor's medical expenses if they are alive during the donation process, and only the recipient's expenses if the donor is deceased.
# Predicted Answer: According to the policy, in the case of a living donor, only the costs of the pre-transplant study protocol for the definitive donor will be covered. This protocol must be approved by the Transplant Committee at the institution where the donation procedure takes place.
#
# The hospitalization costs and medical fees for the surgical team of both the donor and the recipient will also be covered.
#
# For a cadaveric donor, the company will cover the percentage of the procurement cost that corresponds to the recipient according to the rules of the National Transplant Center (CENATRA).
#
# Additionally, the policy states that kidney transplants must comply with the established health regulations by the National Transplant Center (CENATRA).
# F1 Score: 0.3384615384615385
#
# Rouge Score: 0.5
#
# Cosine Similarity: 0.648904026803509
#
# Jaccard Similarity: 0.2037037037037037
#
# Meteor Score: 0.3076923076923077
#
# Question: What is the policy on hyperbaric medicine?
# Ground Truth: According to the conditions, any costs related to Hyperbaric Treatments are not covered, unless specified under coverage 16.
# Predicted Answer: Hyperbaric oxygen therapy is covered under medical supervision for the following conditions:
#
# * Embolism
# * Decompression sickness
# * Cyanide poisoning
# * Carbon monoxide poisoning
# * Chronic osteomyelitis refractory to conventional treatment
# * Second and third-degree burns
# * Radionecrosis of soft tissues
# F1 Score: 0.15789473684210525
#
# Rouge Score: 0.2727272727272727
#
# Cosine Similarity: 0.25732511773283273
#
# Jaccard Similarity: 0.08571428571428572
#
# Meteor Score: 0.15748031496062995
#
# Question: What is the definition of an accident according to the contract?
# Ground Truth: Sudden, unforeseen, and violent event caused by an external factor that results in injuries requiring medical attention to the insured within 90 days subsequent to the event.
# Predicted Answer: According to the contract, there is no specific definition of an "accident" provided in the given context. However, it does mention "Accidente" ( Accident) in various sections, but without a clear definition.
#
# If you would like me to look further or provide more information on related topics, please let me know!
# F1 Score: 0.0
#
# Rouge Score: 0.0
#
# Cosine Similarity: 0.24517195928059626
#
# Jaccard Similarity: 0.0
#
# Meteor Score: 0.0
#
# Question: What is covered during a stay at the hospital?
# Ground Truth: So, according to this information, the following are covered during a stay at the hospital: Private standard room with bathroom, Food provided, Laboratory tests, cabinet, image, and diagnostic agents related to the diagnosis of the covered accident or disease Operating room, healing, recovery, emergency, intensive care, intermediate, or coronary care unit, Blood transfusions and blood compatibility tests, Medications administered in the hospital that comply with the definition in these general conditions, are indicated and justified by the attending physician, and are related to the covered accident or disease, Expenses for an additional bed for the policyholder's companion affected and General nursing care
# Predicted Answer: Based on the provided context, here is the answer:
#
# During a stay at the hospital, the following are covered:
#
# * Hospitalization
# * Medical expenses related to treatment in the hospital
#
# Note that the text does not explicitly mention what is covered during a hospital stay. However, given the context of medical insurance policies, it can be inferred that standard hospital services and medical treatments would typically be included.
# F1 Score: 0.20253164556962022
#
# Rouge Score: 0.12698412698412698
#
# Cosine Similarity: 0.5656017622371117
#
# Jaccard Similarity: 0.11267605633802817
#
# Meteor Score: 0.0912106135986733
#
# Question: What rehabilitation therapy is covered by the insurance?
# Ground Truth: Rehabilitation musculoskeletal (30 sessions), Hydrotherapy (30 sessions), Neurorehabilitation (180 sessions), Therapy for motor disorders (90 sessions), exclusively for newborns with AXA benefit, Speech therapy (30 sessions), Inhalation therapy or pulmonary physiotherapy, as indicated by the attending physician, Cardiac rehabilitation (40 sessions)
# Predicted Answer: Musculoskeletal rehabilitation, hydrotherapy, neurorehabilitation, physical therapy for newborns with AXA benefit, swallowing therapy, neurodevelopmental therapy, respiratory therapy or pulmonary physiotherapy, and cardiopulmonary rehabilitation.
# F1 Score: 0.5128205128205129
#
# Rouge Score: 0.29411764705882354
#
# Cosine Similarity: 0.49351180201319655
#
# Jaccard Similarity: 0.3448275862068966
#
# Meteor Score: 0.33363677742375963
#
# Question: What is the coverage for accidents that need dental work??
# Ground Truth: Consultation of emergency dental care at normal hours once a year without cost, Diagnosis, treatment plan, and prevention, 2 cleanings per year without cost (for adults and children), Radiographs (1 radiograph per year) with 30% co-pay, Dental operation (amalgams and resins) with 30% co-pay, Endodontics (root canal treatments, pulpectomies, and pulpotomias) with 30% co-pay and a 10% discount for other treatments, Minor surgery (minor surgical procedures) with 30% co-pay, Major surgery (major surgical procedures) with a 15% discount, Third molars (wisdom teeth) with a 20% discount, Prosthetics (crowns, onlays, posts) with a 10% discount, Periodontology (1 periodontal evaluation per year without cost) with 30% co-pay and a 10% discount for other treatments, Orthodontics (brackets) with a 10-20% discount for bracket removal, Whitening (Zoom and at-home) with a 20% discount
# Predicted Answer: Based on the provided context, here's a translated answer:
#
# **Coverage for Accidents Requiring Dental Work:**
#
# There is no specific information in the provided text about the coverage for accidents requiring dental work. However, it mentions "Consulta de emergencia dental en horario normal 1 al año sin costo" which translates to "Emergency Dental Consultation within Normal Hours 1 Time per Year at No Cost". This implies that emergency dental consultations are covered under certain plans, but it does not specify if this includes accidents requiring dental work.
#
# To answer your question more accurately, I would recommend verifying the information with a reliable source or contacting AXA Flex Plus directly for clarification.
# F1 Score: 0.1565217391304348
#
# Rouge Score: 0.0891089108910891
#
# Cosine Similarity: 0.17917085464383775
#
# Jaccard Similarity: 0.08490566037735849
#
# Meteor Score: 0.10225478735583701
#
# Question: What is the policy regarding surgery by robot?
# Ground Truth: The policy covers surgery by robot for specific procedures, including prostatectomy, hysterectomy due to endometrial cancer, ovarian cancer, cervical-uterine cancer, renal cancer, and others. However, only surgeons with expertise in minimally invasive surgery and recertification in the relevant specialty will be covered, provided they have performed at least 20 robotic surgeries for that specific procedure.
# Predicted Answer: Severe Minimally Invasive Surgery Assisted by a Robot is covered for the following procedures:
#
# * Prostatectomy
# * Hysterectomy due to Endometrial Cancer
# * Hysterectomy due to Ovarian Cancer
# * Hysterectomy due to Cervico-Uterine Cancer
# * Nephrectomy due to Renal Cancer
# * Partial Nephrectomy due to Renal Cancer
# * Colectomy due to Colonic Cancer
# * Replacement of Mitral Valve
#
# However, any other procedure not listed here will not be covered if performed with robot assistance. Additionally, the surgeon must be a specialist in Minimally Invasive Surgery and have at least 20 (twenty) surgeries using the robot for the specific procedure. If the surgeon does not meet this requirement, the costs related to the surgery will not be paid by AXA.
# F1 Score: 0.5316455696202532
#
# Rouge Score: 0.5526315789473685
#
# Cosine Similarity: 0.6519509675601105
#
# Jaccard Similarity: 0.3620689655172414
#
# Meteor Score: 0.43880964794676985
#
# Question: What is the coverage for COVID-19?
# Ground Truth: For the insured with a policy effective date after February 9, 2022, COVID-19 medical expenses are fully covered if they have completed the complete vaccination schedule as per the National Vaccination Plan. For those without the complete vaccination schedule, COVID-19 medical expenses are partially covered up to $300,000.
# Predicted Answer: Unfortunately, there is no direct mention of "COVID-19" in the provided context information.
#
# However, I can help you determine if COVID-19 might be covered under a specific category. Based on the text, it appears that COVID-19 might be considered an "Enfermedad" (Disease) and therefore potentially covered under the policy.
#
# To confirm this, we would need to look at the specific details of the coverage for diseases (mentioned in section 15). If the policy covers diseases and COVID-19 is a disease, then it could be covered. However, without further information or a clear mention of COVID-19, we cannot say for certain.
#
# If you'd like me to look deeper into this, I can try to compare sections 15 (Enfermedad) with other relevant sections in the policy to see if any specific exclusions or limitations apply to diseases.
# F1 Score: 0.13333333333333333
#
# Rouge Score: 0.15151515151515152
#
# Cosine Similarity: 0.4300446490061428
#
# Jaccard Similarity: 0.07142857142857142
#
# Meteor Score: 0.18452321848211034
#
# Question: What is the coverage for medication outside the hospital?
# Ground Truth: Medicamentos Fuera del Hospital (MFH): Medications purchased outside the hospital are covered, even if other additional coverages such as Emergencia Médica en el Extranjero (EMER), Enfermedades Cubiertas en el Extranjero (ECE), or Atención en el Extranjero (ATEX) are contracted.
# Predicted Answer: Medication costs outside of the hospital are covered when administered by a legally authorized nurse under the prescription of a doctor, specifically for medications that require special handling, preparation, or administration. This coverage includes medications for respiratory rehabilitation and parenteral nutrition at home.
# F1 Score: 0.16326530612244897
#
# Rouge Score: 0.12903225806451613
#
# Cosine Similarity: 0.20120081132312223
#
# Jaccard Similarity: 0.08888888888888889
#
# Meteor Score: 0.14622950819672131
#
# Question: What is your deductible for an accident?
# Ground Truth: $0 (zero pesos), as per the policy conditions, after the accidental coverage has been contracted. The deductible will only be applicable if the total cost of the accident is less than $2,000.
# Predicted Answer: According to the policy conditions, the deductible for an accident is $0 (zero pesos) if the total cost of medical expenses is superior to $2,000 (two thousand pesos 00/100 national currency). This is a result of the modification made by the Company in the basic coverage upon contracting this additional coverage.
# F1 Score: 0.5106382978723405
#
# Rouge Score: 0.7058823529411765
#
# Cosine Similarity: 0.6859943405700355
#
# Jaccard Similarity: 0.34285714285714286
#
# Meteor Score: 0.5861186630417399
#
# Question: What is the coverage if you are out of country?
# Ground Truth: Enfermedades Cubiertas en el Extranjero (ECE), if you are out of country, this coverage provides medical expenses for certain diseases such as cancer and cerebrovascular/cerebral diseases, but only if the diagnosis and initial costs occurred within Mexico.
# Predicted Answer: According to the policy, there is a special provision for hospitalizations abroad (out of country). To be eligible, you must:
#
# * Notify the company from the onset of illness or within 10 days after diagnosis
# * Or notify the company 10 days before being hospitalized abroad and not have started medical treatment related to that illness
#
# This provision only applies if you have additional coverage with cost: Foreign Treatment (ATEX) and Covered Diseases Abroad (ECE).
#
# Note: This provision also applies to subsequent surgeries related to the same illness, as long as you had this benefit from the first surgery.
#
# The coverage includes hospital event expenses, including medical fees. The diagnosis is determined by initial medical information provided by your doctor and any studies that confirm the illness.
#
# There is a 5% co-insurance reduction for this benefit, which can be applied once you meet the above conditions.
# F1 Score: 0.22222222222222224
#
# Rouge Score: 0.391304347826087
#
# Cosine Similarity: 0.3824488732896837
#
# Jaccard Similarity: 0.125
#
# Meteor Score: 0.1929824561403509
#
# Question: What is Planmed?
# Ground Truth: Planmed is a medical coverage offered by AXA Flex Plus 2024, providing benefits such as Check Up, Consultas de Atención Primaria (Primary Care), Atención no programada (Non-programmed Attention), and Consultas de Especialidad (Specialty Consultations).
# Predicted Answer: Planmed is the name of the medical coverage or insurance plan being referred to in the document.
# F1 Score: 0.1875
#
# Rouge Score: 0.1111111111111111
#
# Cosine Similarity: 0.1318760946791574
#
# Jaccard Similarity: 0.10344827586206896
#
# Meteor Score: 0.14820717131474104
#
# Question: What are the rules if I get injured in a racecar?
# Ground Truth: According to section 35 of the policy, injuries sustained by the insured while traveling as an occupant (driver or passenger) of a vehicle, including a racecar, during racing, endurance, or speed tests, are not covered.
# Predicted Answer: If you get injured while traveling as an occupant of a vehicle (driver or copilot) or motorcycle in races, speed tests, or any other similar competitions, or while participating in motor sports with a vehicle in any modality, your injury will be covered.
# F1 Score: 0.3684210526315789
#
# Rouge Score: 0.3684210526315789
#
# Cosine Similarity: 0.4369519672644266
#
# Jaccard Similarity: 0.22580645161290322
#
# Meteor Score: 0.38952879581151834
#
# Question: What is the coverage for a heart attack?
# Ground Truth: Coverage includes surgical intervention for coronary heart disease, provided the need for such interventions is demonstrated through coronary angiography.
# Predicted Answer: The coverage for a heart attack (infarto del miocardio) includes medical intervention through open chest surgery for myocardial revascularization. The need for this type of intervention must be demonstrated through coronary angiography.
# F1 Score: 0.5
#
# Rouge Score: 0.6153846153846154
#
# Cosine Similarity: 0.6359630007488936
#
# Jaccard Similarity: 0.3333333333333333
#
# Meteor Score: 0.4987475398103418
#
# Question: What is the coverage for a heart transplant?
# Ground Truth: The coverage for a heart transplant includes: The surgical procedure, Hospitalization expenses (as per the contracted table), Donor-related expenses, including those incurred by the donor during the donation process, Expenses related to procurement and transportation are not covered.
# Predicted Answer: The coverage includes only the surgical procedure for heart transplants, excluding post-surgical expenses. The costs of the donor are also covered in case of a living donor, but only the costs of the recipient are covered in case of a cadaveric donor.
#
# Note: I've translated the relevant section from Spanish to English:
#
# "Se cubren los gastos del donante por Trasplante de Órganos. En caso de un donante vivo, se consideran gastos cubiertos los gastos médicos en que incurra el donante durante el acto quirúrgico de donación, excluyendo gastos pre y postquirúrgicos de donación..."
#
# becomes:
#
# "The costs of the donor are also covered in case of a living donor, but only the costs of the donor that occur during the surgical procedure of donation..."
# F1 Score: 0.2465753424657534
#
# Rouge Score: 0.375
#
# Cosine Similarity: 0.5413568387771196
#
# Jaccard Similarity: 0.140625
#
# Meteor Score: 0.26714392327040537
#
# Question: What is the coverage for a kidney transplant?
# Ground Truth: This policy covers the procedure for kidney transplantation, but excludes post-surgical costs. Additionally, it also covers the donor's medical expenses if they are alive during the donation process, and only the recipient's expenses if the donor is deceased.
# Predicted Answer: In the case where the transplanted organ comes from a living donor, only the costs of the donor's pre-transplant study protocol will be covered. This protocol must be approved by the Transplant Committee at the institution where the donation procedure takes place. The costs of hospitalization for the donor and the medical team's honorarium are also covered.
#
# The costs of honorarium generated by the donor's pre-transplant study protocol and the surgical procedures of the recipient and donor will be covered in accordance with the contracted tariff.
#
# In the case of a cadaveric donor, the Company will cover the percentage of the cost of procurement that corresponds to the recipient, in accordance with the rules of the National Transplant Center (CENATRA).
#
# Kidney transplants must comply with the health regulations established by CENATRA.
#
# Transportation and organ handling costs are not covered.
# F1 Score: 0.2571428571428572
#
# Rouge Score: 0.4090909090909091
#
# Cosine Similarity: 0.6227453978369328
#
# Jaccard Similarity: 0.14754098360655737
#
# Meteor Score: 0.3064017577834052
#
# Question: What is the policy on hyperbaric medicine?
# Ground Truth: According to the conditions, any costs related to Hyperbaric Treatments are not covered, unless specified under coverage 16.
# Predicted Answer: Hyperbaric treatment is covered under medical supervision for the following conditions:
#
# * Gas embolism
# * Decompression sickness
# * Cyanide poisoning
# * Carbon monoxide poisoning
# * Chronic osteomyelitis refractory to conventional treatment
# * Second and third-degree burns
# * Radiation necrosis of soft tissues
# F1 Score: 0.15789473684210525
#
# Rouge Score: 0.2727272727272727
#
# Cosine Similarity: 0.24748737341529164
#
# Jaccard Similarity: 0.08571428571428572
#
# Meteor Score: 0.15625
#
# Question: What is the definition of an accident according to the contract?
# Ground Truth: Sudden, unforeseen, and violent event caused by an external factor that results in injuries requiring medical attention to the insured within 90 days subsequent to the event.
# Predicted Answer: According to Article 69 of the contract, there is no specific definition of what constitutes an "accident" (referred to as "Siniestro"). However, based on the surrounding context and other articles in the contract, it can be inferred that any unforeseen event or occurrence that results in medical expenses or financial loss is considered a potential accident under this insurance policy.
#
# However, if you're looking for specific information about accidents, I'd like to point out that there's an article (28. Pago de Indemnizaciones de Siniestros) that discusses payment of indemnities for accidents, but it doesn't provide a definition of what constitutes an accident.
#
# If you have any further questions or would like me to clarify anything, please let me know!
# F1 Score: 0.12121212121212122
#
# Rouge Score: 0.2222222222222222
#
# Cosine Similarity: 0.344287930371216
#
# Jaccard Similarity: 0.06451612903225806
#
# Meteor Score: 0.11261261261261261
#
# Question: What is covered during a stay at the hospital?
# Ground Truth: So, according to this information, the following are covered during a stay at the hospital: Private standard room with bathroom, Food provided, Laboratory tests, cabinet, image, and diagnostic agents related to the diagnosis of the covered accident or disease Operating room, healing, recovery, emergency, intensive care, intermediate, or coronary care unit, Blood transfusions and blood compatibility tests, Medications administered in the hospital that comply with the definition in these general conditions, are indicated and justified by the attending physician, and are related to the covered accident or disease, Expenses for an additional bed for the policyholder's companion affected and General nursing care
# Predicted Answer: During a stay at the hospital, the following are covered:
#
# * Hospitalization costs
# * Medical expenses related to the administration of medications that require special handling, preparation, and/or administration
# * Rehabilitation pulmonary therapy
# * Parenteral alimentation at home
# * Costs for medical treatment and surgery derived from benign and malignant tumors of the central nervous system, as well as vascular malformations or circulatory apparatus located in the central nervous system, ischemia, thrombosis, and cerebral hemorrhage.
# F1 Score: 0.15384615384615385
#
# Rouge Score: 0.1111111111111111
#
# Cosine Similarity: 0.5668434311252412
#
# Jaccard Similarity: 0.08333333333333333
#
# Meteor Score: 0.06525285481239804
#
# Question: What rehabilitation therapy is covered by the insurance?
# Ground Truth: Rehabilitation musculoskeletal (30 sessions), Hydrotherapy (30 sessions), Neurorehabilitation (180 sessions), Therapy for motor disorders (90 sessions), exclusively for newborns with AXA benefit, Speech therapy (30 sessions), Inhalation therapy or pulmonary physiotherapy, as indicated by the attending physician, Cardiac rehabilitation (40 sessions)
# Predicted Answer: The following rehabilitation therapies are covered by the insurance:
#
# * Rehabilitation musculoesquelética (Musculoskeletal rehabilitation) - up to 30 sessions
# * Hidroterapia (Hydrotherapy) - up to 30 sessions
# * Neurorehabilitación (Neurorehabilitation) - up to 180 sessions
# * Terapia psicomotora (Psychomotor therapy) - up to 90 sessions for newborns with AXA benefit
# * Terapia para deglución (Swallowing therapy) - up to 30 sessions
# * Neurodesarrollo (Neurodevelopment) - up to 365 sessions
# * Inhaloterapia or fisioterapia pulmonar (Pulmonary physical therapy) - as indicated by the treating physician
#
# Note: The insurance company may request additional documentation to confirm the medical necessity of these therapies.
# F1 Score: 0.43478260869565216
#
# Rouge Score: 0.4411764705882353
#
# Cosine Similarity: 0.5817153680514656
#
# Jaccard Similarity: 0.2777777777777778
#
# Meteor Score: 0.6109589041095891
#
# Question: What is the coverage for accidents that need dental work??
# Ground Truth: Consultation of emergency dental care at normal hours once a year without cost, Diagnosis, treatment plan, and prevention, 2 cleanings per year without cost (for adults and children), Radiographs (1 radiograph per year) with 30% co-pay, Dental operation (amalgams and resins) with 30% co-pay, Endodontics (root canal treatments, pulpectomies, and pulpotomias) with 30% co-pay and a 10% discount for other treatments, Minor surgery (minor surgical procedures) with 30% co-pay, Major surgery (major surgical procedures) with a 15% discount, Third molars (wisdom teeth) with a 20% discount, Prosthetics (crowns, onlays, posts) with a 10% discount, Periodontology (1 periodontal evaluation per year without cost) with 30% co-pay and a 10% discount for other treatments, Orthodontics (brackets) with a 10-20% discount for bracket removal, Whitening (Zoom and at-home) with a 20% discount
# Predicted Answer: Here's a clear and concise answer:
#
# The coverage for accidental dental injuries includes:
#
# * Emergency dental consultation without cost
# * Diagnosis, treatment plan, and prevention (2 cleanings per year without cost for adults and children)
# * Radiography (1 radiograph per year without cost) with 30% copayment
# * Dental operation (amalgams and resins) with 30% copayment
# * Endodontic treatments (root canal treatments, pulpectomies, and pulpotomias) with 30% copayment and a 10% discount for other treatments
# * Basic surgery (minor surgical procedures) with 30% copayment
# * Advanced surgery (major surgical procedures) with discounts starting from 15%
# * Third molars (wisdom teeth) with discounts starting from 20%
# * Prosthetics (crowns, onlays, posts) with discounts starting from 10%
#
# Please note that some of these services have co-payments or copayments.
# F1 Score: 0.7154471544715446
#
# Rouge Score: 0.43564356435643564
#
# Cosine Similarity: 0.7519766050479542
#
# Jaccard Similarity: 0.5569620253164557
#
# Meteor Score: 0.6024096385542169
#
# Question: What is the policy regarding surgery by robot?
# Ground Truth: The policy covers surgery by robot for specific procedures, including prostatectomy, hysterectomy due to endometrial cancer, ovarian cancer, cervical-uterine cancer, renal cancer, and others. However, only surgeons with expertise in minimally invasive surgery and recertification in the relevant specialty will be covered, provided they have performed at least 20 robotic surgeries for that specific procedure.
# Predicted Answer: The policy states that only the following surgical procedures performed with robotic assistance are covered:
#
# • Prostatectomy
# • Hysterectomy due to endometrial cancer
# • Hysterectomy due to ovarian cancer
# • Hysterectomy due to cervical-uterine cancer
# • Nephrectomy due to renal cancer
# • Partial nephrectomy due to renal cancer
# • Colectomy due to colon cancer
# • Replacement of the mitral valve
#
# Any other surgical procedure performed with robotic assistance is not covered.
#
# A requirement for coverage is that the surgeon must be a specialist in minimally invasive surgery with valid recertification and have performed at least 20 procedures using the robot.
# F1 Score: 0.6027397260273972
#
# Rouge Score: 0.5789473684210527
#
# Cosine Similarity: 0.6536170054958924
#
# Jaccard Similarity: 0.43137254901960786
#
# Meteor Score: 0.48875545888688066
#
# Question: What is the coverage for COVID-19?
# Ground Truth: For the insured with a policy effective date after February 9, 2022, COVID-19 medical expenses are fully covered if they have completed the complete vaccination schedule as per the National Vaccination Plan. For those without the complete vaccination schedule, COVID-19 medical expenses are partially covered up to $300,000.
# Predicted Answer: Unfortunately, there is no direct mention of "COVID-19" in the provided context information.
#
# However, based on the descriptions, I can infer that COVID-19 would likely be covered under "Enfermedad" (Illness or Disease) as described in article 15. This implies that any alteration of health resulting from internal or external agents, requiring medical treatment, would be considered an illness and potentially be covered.
#
# However, to confirm this, we would need specific information about how COVID-19 is explicitly mentioned within the contract's conditions.
# F1 Score: 0.12307692307692307
#
# Rouge Score: 0.12121212121212122
#
# Cosine Similarity: 0.3009641002687813
#
# Jaccard Similarity: 0.06557377049180328
#
# Meteor Score: 0.18139367816091956
#
# Question: What is the coverage for medication outside the hospital?
# Ground Truth: Medicamentos Fuera del Hospital (MFH): Medications purchased outside the hospital are covered, even if other additional coverages such as Emergencia Médica en el Extranjero (EMER), Enfermedades Cubiertas en el Extranjero (ECE), or Atención en el Extranjero (ATEX) are contracted.
# Predicted Answer: According to the policy, "Medicamentos" (medications) are covered outside the hospital as part of a patient's home care. Specifically, it covers medications that require special handling, preparation, and administration under medical prescription.
#
# The coverage includes:
#
# * Medications for which the prescribing doctor has authorized an enrolled nurse or other healthcare professional to administer.
# * Rehabilitation pulmonary treatment
# * Parenteral nutrition administered at home
#
# This coverage is limited to a maximum of 30 consecutive days or 720 hours in non-continuous periods, and only one session per day is covered.
# F1 Score: 0.13513513513513514
#
# Rouge Score: 0.16129032258064516
#
# Cosine Similarity: 0.22024637446794104
#
# Jaccard Similarity: 0.07246376811594203
#
# Meteor Score: 0.12766134397870926
#
# Question: What is your deductible for an accident?
# Ground Truth: $0 (zero pesos), as per the policy conditions, after the accidental coverage has been contracted. The deductible will only be applicable if the total cost of the accident is less than $2,000.
# Predicted Answer: According to the policy conditions, the deductible for an accident is $0 (zero pesos) as long as the total amount of expenses covered exceeds $2,000.
#
# (Note: DED0 in the original text stands for "Deducible Cero por Accidente", which translates to "Zero Deductible for Accidents".)
# F1 Score: 0.45454545454545453
#
# Rouge Score: 0.5882352941176471
#
# Cosine Similarity: 0.5731513024140633
#
# Jaccard Similarity: 0.29411764705882354
#
# Meteor Score: 0.43887930251566604
#
# Question: What is the coverage if you are out of country?
# Ground Truth: Enfermedades Cubiertas en el Extranjero (ECE), if you are out of country, this coverage provides medical expenses for certain diseases such as cancer and cerebrovascular/cerebral diseases, but only if the diagnosis and initial costs occurred within Mexico.
# Predicted Answer: For Hospitalizations abroad, coverage applies provided:
#
# * You notify the Company within 10 days after diagnosis or,
# * You notify the Company 10 days before hospitalization abroad and,
# * No medical treatment has been initiated due to the illness.
#
# This only applies if you have an additional coverage with a cost: Foreign Attention (FA) and Covered Illnesses Abroad (CIA).
#
# For subsequent surgeries on the same illness, this benefit applies if it was covered from the first surgery.
#
# The benefit only covers planned hospital events, including medical fees.
#
# Diagnosis is determined by initial medical information provided by the doctor who established the final diagnosis, as well as studies that confirmed the illness.
# F1 Score: 0.14925373134328357
#
# Rouge Score: 0.21739130434782608
#
# Cosine Similarity: 0.3659942110514743
#
# Jaccard Similarity: 0.08064516129032258
#
# Meteor Score: 0.12962962962962962
#
# Question: What is Planmed?
# Ground Truth: Planmed is a medical coverage offered by AXA Flex Plus 2024, providing benefits such as Check Up, Consultas de Atención Primaria (Primary Care), Atención no programada (Non-programmed Attention), and Consultas de Especialidad (Specialty Consultations).
# Predicted Answer: Planmed refers to a coverage or insurance plan that includes benefits such as Check Up, Consultas de Atención Primaria (Primary Care), Atención no programada (Non-programmed care), and Consultas de Especialidad (Specialized consultations).
# F1 Score: 0.6818181818181818
#
# Rouge Score: 0.5555555555555556
#
# Cosine Similarity: 0.7500000000000003
#
# Jaccard Similarity: 0.5172413793103449
#
# Meteor Score: 0.6543325472788644
#
# Question: What are the rules if I get injured in a racecar?
# Ground Truth: According to section 35 of the policy, injuries sustained by the insured while traveling as an occupant (driver or passenger) of a vehicle, including a racecar, during racing, endurance, or speed tests, are not covered.
# Predicted Answer: If you suffer injuries as an occupant of any vehicle (driver or copilot) participating in races, trials of endurance or speed, motorcycling, or practicing sports with a motorized vehicle, this is not covered by the policy.
#
# However, if you participate in a championship approved by National or International Federations and suffer injuries or illnesses as a result, or if you are injured while traveling as a pilot, passenger, mechanic, or crew member of an airplane that does not belong to a commercially licensed airline with regular schedules, this is covered.
# F1 Score: 0.3389830508474576
#
# Rouge Score: 0.5263157894736842
#
# Cosine Similarity: 0.5721929504035135
#
# Jaccard Similarity: 0.20408163265306123
#
# Meteor Score: 0.3668639053254438
#
# Question: What is the coverage for a heart attack?
# Ground Truth: Coverage includes surgical intervention for coronary heart disease, provided the need for such interventions is demonstrated through coronary angiography.
# Predicted Answer: Based on the provided context, the coverage for a heart attack is:
#
# Myocardial infarction (section f)
#
# This includes coverage for interventions such as coronary angiography, revascularization of the myocardium through hemoducts, and surgical procedures, excluding complications like thrombosis.
# F1 Score: 0.4571428571428571
#
# Rouge Score: 0.6153846153846154
#
# Cosine Similarity: 0.6148754619013456
#
# Jaccard Similarity: 0.2962962962962963
#
# Meteor Score: 0.3773271276595745
#
# Question: What is the coverage for a heart transplant?
# Ground Truth: The coverage for a heart transplant includes: The surgical procedure, Hospitalization expenses (as per the contracted table), Donor-related expenses, including those incurred by the donor during the donation process, Expenses related to procurement and transportation are not covered.
# ...
# Predicted Answer: Here are the types of rehabilitation therapies that are covered:
#
# * Musculoskeletal rehabilitation (up to 30 sessions)
# * Hydrotherapy (up to 30 sessions)
# * Neurorehabilitation (up to 180 sessions)
# * Therapeutic motor activity, only for newborns with AXA benefits (up to 90 sessions)
# * Deglutition therapy (up to 30 sessions)
# * Neurodevelopmental therapy (up to 365 sessions)
#
# Note that the insurance company may request additional documentation to confirm the medical necessity of these therapies.
# F1 Score: 0.43636363636363634
#
# Rouge Score: 0.35294117647058826
#
# Cosine Similarity: 0.5311150395267658
#
# Jaccard Similarity: 0.27906976744186046
#
# Meteor Score: 0.6265696245975497
#
# Question: What is the coverage for accidents that need dental work??
# Ground Truth: Consultation of emergency dental care at normal hours once a year without cost, Diagnosis, treatment plan, and prevention, 2 cleanings per year without cost (for adults and children), Radiographs (1 radiograph per year) with 30% co-pay, Dental operation (amalgams and resins) with 30% co-pay, Endodontics (root canal treatments, pulpectomies, and pulpotomias) with 30% co-pay and a 10% discount for other treatments, Minor surgery (minor surgical procedures) with 30% co-pay, Major surgery (major surgical procedures) with a 15% discount, Third molars (wisdom teeth) with a 20% discount, Prosthetics (crowns, onlays, posts) with a 10% discount, Periodontology (1 periodontal evaluation per year without cost) with 30% co-pay and a 10% discount for other treatments, Orthodontics (brackets) with a 10-20% discount for bracket removal, Whitening (Zoom and at-home) with a 20% discount
# Predicted Answer: Based on the provided context, here's a translation of the relevant information:
#
# * "Servicios de Asistencia incluidos" translates to "Included Services"
# * "Protección Dental" translates to "Dental Protection"
# * "Suma Asegurada de 35 UMAM" translates to "Coverage Limit of 35 Universal Medical Allowance Units"
#
# Here's the coverage for accidents that need dental work:
#
# For **Dental Protection** (Plan Básico), the coverage includes:
#
# * Consultation emergency dental service, 1 time per year, no cost
# * Diagnosis, treatment plan, and prevention, with 0% co-pay
# * Limpiezas (cleanings) for adults and children, 2 times per year, free of charge
# * Radiografías (X-rays), 1 time per year, with a 30% co-pay
# * Operatoria dental (dental procedures such as fillings and crowns), with a 30% co-pay
# * Endodoncias (root canal treatments), with a 30% co-pay and a 10% discount on other treatments
# * Cirugía básica (basic surgery), with a 30% co-pay
# * Cirugía avanzada (advanced surgery), with discounts starting from 15%
# * Terceros molares (wisdom teeth removal), with discounts starting from 20%
# * Prótesis (dental crowns and bridges), with a discount of 10%
# * Peridoncia (periodontal evaluation), free of charge, with a 30% co-pay on other treatments
# * Ortodoncia (orthodontic treatment), with discounts for bracket removal between 10% to 20%
#
# For **Dental Protection Integral** (PDI), the coverage includes:
#
# * All the services listed above, including:
# 	+ Consultation emergency dental service, 1 time per year, no cost
# 	+ Diagnosis, treatment plan, and prevention, with 0% co-pay
# 	+ Limpiezas (cleanings) for adults and children, 2 times per year, free of charge
# 	+ Radiografías (X-rays), 1 time per year, with a 30% co-pay
# 	+ Operatoria dental (dental procedures such as fillings and crowns), with a 30% co-pay
# 	+ Endodoncias (root canal treatments), with a 30% co-pay
# 	+ Cirugía básica (basic surgery), with a 30% co-pay
# 	+ Cirugía avanzada (advanced surgery), with a 30% co-pay
# 	+ Terceros molares (wisdom teeth removal), with a 30% co-pay
# 	+ Prótesis (dental crowns and bridges), with a 50% co-pay
# 	+ Peridoncia (periodontal evaluation), free of charge, with a 30% co-pay on other treatments
#
# Please note that the coverage details may vary depending on the specific plan and policy.
# F1 Score: 0.41463414634146345
#
# Rouge Score: 0.33663366336633666
#
# Cosine Similarity: 0.7384767812781744
#
# Jaccard Similarity: 0.26153846153846155
#
# Meteor Score: 0.4649331456720619
#
# Question: What is the policy regarding surgery by robot?
# Ground Truth: The policy covers surgery by robot for specific procedures, including prostatectomy, hysterectomy due to endometrial cancer, ovarian cancer, cervical-uterine cancer, renal cancer, and others. However, only surgeons with expertise in minimally invasive surgery and recertification in the relevant specialty will be covered, provided they have performed at least 20 robotic surgeries for that specific procedure.
# Predicted Answer: The policy states that only the following robotic surgeries are covered:
#
# * Prostatectomy
# * Hysterectomy for endometrial cancer
# * Hysterectomy for ovarian cancer
# * Hysterectomy for cervical-uterine cancer
# * Nephrectomy for renal cancer
# * Partial nephrectomy for renal cancer
# * Colectomy for colon cancer
# * Valve replacement surgery (specifically, mitral valve replacement)
#
# Any other robotic surgery not listed is not covered. To be eligible for coverage, the surgeon must be a specialist in minimally invasive surgery with up-to-date recertification and have performed at least 20 robot-assisted surgeries of the same type.
# F1 Score: 0.5555555555555556
#
# Rouge Score: 0.5263157894736842
#
# Cosine Similarity: 0.7001149127744017
#
# Jaccard Similarity: 0.38461538461538464
#
# Meteor Score: 0.4961421912630049
#
# Question: What is the coverage for COVID-19?
# Ground Truth: For the insured with a policy effective date after February 9, 2022, COVID-19 medical expenses are fully covered if they have completed the complete vaccination schedule as per the National Vaccination Plan. For those without the complete vaccination schedule, COVID-19 medical expenses are partially covered up to $300,000.
# Predicted Answer: Unfortunately, there is no explicit mention of COVID-19 in the provided text. However, based on the definitions and exclusions listed, it appears that COVID-19 would be considered an "Enfermedad" (Disease) under the contract.
#
# Since COVID-19 is not explicitly mentioned, we can infer its coverage based on the definition of "Enfermedad" in section 15. According to this definition, any alteration of health requiring medical treatment or surgery would be covered, provided it does not fall under one of the exclusions listed later (such as mental disorders, obesity treatments, etc.).
#
# Therefore, assuming COVID-19 meets the criteria for an "Enfermedad", it would likely be covered under this contract.
# F1 Score: 0.11267605633802817
#
# Rouge Score: 0.12121212121212122
#
# Cosine Similarity: 0.3568244060254587
#
# Jaccard Similarity: 0.05970149253731343
#
# Meteor Score: 0.158573124540675
#
# Question: What is the coverage for medication outside the hospital?
# Ground Truth: Medicamentos Fuera del Hospital (MFH): Medications purchased outside the hospital are covered, even if other additional coverages such as Emergencia Médica en el Extranjero (EMER), Enfermedades Cubiertas en el Extranjero (ECE), or Atención en el Extranjero (ATEX) are contracted.
# Predicted Answer: The coverage for medication outside the hospital includes administration, preparation, and/or administration of specialized medications that require management under a doctor's prescription. This will be paid for a maximum period of 30 days continuously or 720 hours in discontinuous periods per incident. The amount for this concept is subject to what is stipulated in the contracted table.
#
# (Note: "Enfermería" translates to "Nursing" or "Home healthcare")
# F1 Score: 0.13114754098360656
#
# Rouge Score: 0.12903225806451613
#
# Cosine Similarity: 0.15364425591947517
#
# Jaccard Similarity: 0.07017543859649122
#
# Meteor Score: 0.11735015772870662
#
# Question: What is your deductible for an accident?
# Ground Truth: $0 (zero pesos), as per the policy conditions, after the accidental coverage has been contracted. The deductible will only be applicable if the total cost of the accident is less than $2,000.
# Predicted Answer: According to the policy conditions, there is a Deducible Zero for Accident (DED0). The company modifies the deductible in the basic coverage to zero pesos ($0) in case of an accident, provided that the total amount of covered expenses is superior to $2,000.
#
# So, the answer is: $0
# F1 Score: 0.5365853658536585
#
# Rouge Score: 0.6470588235294118
#
# Cosine Similarity: 0.6608622444116106
#
# Jaccard Similarity: 0.36666666666666664
#
# Meteor Score: 0.4935720844811754
#
# Question: What is the coverage if you are out of country?
# Ground Truth: Enfermedades Cubiertas en el Extranjero (ECE), if you are out of country, this coverage provides medical expenses for certain diseases such as cancer and cerebrovascular/cerebral diseases, but only if the diagnosis and initial costs occurred within Mexico.
# Predicted Answer: For Hospitalizations abroad, coverage applies if:
#
# * The Company is notified within 10 days after diagnosis or
# * Notification is given to the Company 10 days before hospital admission in a foreign country and
# * No medical treatment has been initiated for the illness.
#
# This only applies if the policyholder has additional coverages with costs, such as International Medical Assistance (IMA) and Illnesses Covered Abroad (ICA).
#
# For subsequent surgeries related to the same illness, this benefit applies if the policyholder had this coverage from the first surgery. The benefit only covers the planned hospital event, including medical fees.
#
# The diagnosis will be determined based on initial medical information provided by the doctor who made the definitive diagnosis, as well as any studies that confirmed the illness.
#
# Once the policyholder has met these conditions, a 5% co-insurance discount applies to hospital expenses, as specified in the policy contract.
# F1 Score: 0.19047619047619047
#
# Rouge Score: 0.34782608695652173
#
# Cosine Similarity: 0.3647170090013082
#
# Jaccard Similarity: 0.10526315789473684
#
# Meteor Score: 0.15570934256055366
#
# Question: What is Planmed?
# Ground Truth: Planmed is a medical coverage offered by AXA Flex Plus 2024, providing benefits such as Check Up, Consultas de Atención Primaria (Primary Care), Atención no programada (Non-programmed Attention), and Consultas de Especialidad (Specialty Consultations).
# Predicted Answer: Planmed refers to a medical coverage or plan that provides benefits such as Check Up, Consultas de Atención Primaria (Primary Care Consultations), Atención no programada (Urgent Care), and Consultas de Especialidad (Specialty Consultations).
# F1 Score: 0.6976744186046512
#
# Rouge Score: 0.5555555555555556
#
# Cosine Similarity: 0.7563225565351136
#
# Jaccard Similarity: 0.5357142857142857
#
# Meteor Score: 0.7330056179775281
#
# Question: What are the rules if I get injured in a racecar?
# Ground Truth: According to section 35 of the policy, injuries sustained by the insured while traveling as an occupant (driver or passenger) of a vehicle, including a racecar, during racing, endurance, or speed tests, are not covered.
# Predicted Answer: If you suffer an injury while traveling as an occupant of any vehicle (driver or copilot) in races, speed tests, or high-speed events, this is covered under point 35. However, it's essential to note that the accident must occur in a non-regular service flight, which means a commercial airline with scheduled flights and regular schedules does not qualify.
#
# The injury will be covered as long as you were not participating in a professional racing event or a competition sanctioned by national or international Federations.
# F1 Score: 0.29508196721311475
#
# Rouge Score: 0.47368421052631576
#
# Cosine Similarity: 0.507406265350415
#
# Jaccard Similarity: 0.17307692307692307
#
# Meteor Score: 0.316487032029554
#
# Question: What is the coverage for a heart attack?
# Ground Truth: Coverage includes surgical intervention for coronary heart disease, provided the need for such interventions is demonstrated through coronary angiography.
# Predicted Answer: The coverage for a heart attack is included under "f. Enfermedades renales" no, actually under  "Enfermedades de las coronarias que requieren cirugía".
# F1 Score: 0.15384615384615383
#
# Rouge Score: 0.15384615384615385
#
# Cosine Similarity: 0.2553769592276246
#
# Jaccard Similarity: 0.08333333333333333
#
# Meteor Score: 0.11363636363636363
#
# Question: What is the coverage for a heart transplant?
# Ground Truth: The coverage for a heart transplant includes: The surgical procedure, Hospitalization expenses (as per the contracted table), Donor-related expenses, including those incurred by the donor during the donation process, Expenses related to procurement and transportation are not covered.
# Predicted Answer: The coverage for a heart transplant is covered exclusively under section d. Trasplantes de Órganos (Transplants of Organs), which includes:
#
# * The procedure for the transplant of the heart, excluding post-quirurgical costs.
# * The expenses of the donor, including medical expenses incurred by the donor during the surgical act of donation.
#
# Note: This coverage is only applicable if the donor is alive. If the donor is cadaveric, the expenses will be covered solely for the recipient.
# F1 Score: 0.47058823529411764
#
# Rouge Score: 0.5
#
# Cosine Similarity: 0.7178585914233043
#
# Jaccard Similarity: 0.3076923076923077
#
# Meteor Score: 0.29296875
#
# Question: What is the coverage for a kidney transplant?
# Ground Truth: This policy covers the procedure for kidney transplantation, but excludes post-surgical costs. Additionally, it also covers the donor's medical expenses if they are alive during the donation process, and only the recipient's expenses if the donor is deceased.
# Predicted Answer: In the case where the transplanted organ comes from a live donor, only the costs of the pre-transplant study protocol for the definitive donor will be covered. This protocol must be approved by the Transplant Committee of the institution where the donation procedure is performed.
#
# For a cadaveric donor, the Company will cover the percentage of the cost of procurement that corresponds to the recipient according to the rules of the National Transplant Center of the Ministry of Health (CENATRA).
#
# The costs of hospitalization and medical fees for both the donor and the recipient will be covered in accordance with the contracted tariff.
#
# Transplants must comply with the health regulations established by the CENATRA.
#
# The costs of transportation and handling of the organ are not covered.
# F1 Score: 0.1818181818181818
#
# Rouge Score: 0.2727272727272727
#
# Cosine Similarity: 0.6101723878465136
#
# Jaccard Similarity: 0.1
#
# Meteor Score: 0.1923076923076923
#
# Question: What is the policy on hyperbaric medicine?
# Ground Truth: According to the conditions, any costs related to Hyperbaric Treatments are not covered, unless specified under coverage 16.
# Predicted Answer: According to section 16 of the policy, "Hyperbaric Medicine" is covered under certain medical conditions with medical supervision. The following diseases are included:
#
# * Embolism gas
# * Decompression sickness diseases
# * Cyanide poisoning
# * Carbon monoxide poisoning
# * Chronic osteomyelitis refractory to conventional treatment
# * Second and third-degree burns
# * Radiation necrosis of soft tissues
# F1 Score: 0.21739130434782608
#
# Rouge Score: 0.45454545454545453
#
# Cosine Similarity: 0.3721889173040143
#
# Jaccard Similarity: 0.12195121951219512
#
# Meteor Score: 0.218978102189781
#
# Average F1 Score over 10 runs: 0.3106647350739398
# Average Rouge Score over 10 runs: 0.33121792251975757
# Average Cosine Similarity over 10 runs: 0.46966313868566645
# Average Jaccard Similarity over 10 runs: 0.19990852134847784
# Average Meteor Score over 10 runs: 0.29444956107455095
